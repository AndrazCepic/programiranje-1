# %% [markdown]
# # ANALIZA MAČKOV/MAČKONK!

# %%
import macke_r
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-be97862d72e7> in <module>
# ----> 1 import macke_r
#
# ModuleNotFoundError: No module named 'macke_r'
